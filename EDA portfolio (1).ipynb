# %%
# https://www.kaggle.com/datasets/aiaiaidavid/the-big-dataset-of-ultra-marathon-running/discussion/420633

# %%
import pandas as pd
import seaborn as sns

# %%
# Let's look at the data
df = pd.read_csv('TWO_CENTURIES_OF_UM_RACES.csv')
df.head()
# Out:
# C:\Users\pedre\AppData\Local\Temp\ipykernel_16644\2079840566.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('TWO_CENTURIES_OF_UM_RACES.csv')
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance        Athlete club  \
# 0                         22           4:51:39 h               Tnfrc
# 1                         22           5:15:45 h  Roberto Echeverría
# 2                         22           5:16:44 h   Puro Trail Osorno
# 3                         22           5:34:13 h            Columbia
# 4                         22           5:54:14 h      Baguales Trail
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
# 2             CHI                 1987.0              M                  M23
# 3             ARG                 1976.0              M                  M40
# 4             CHI                 1992.0              M                  M23
#
#   Athlete average speed  Athlete ID
# 0                10.286           0
# 1                 9.501           1
# 2                 9.472           2
# 3                 8.976           3
# 4                 8.469           4

# %%
# Let's make all columns labels lower case
df.columns = df.columns.str.lower()
df.head()
# Out:
#    year of event event dates           event name event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    event number of finishers athlete performance        athlete club  \
# 0                         22           4:51:39 h               Tnfrc
# 1                         22           5:15:45 h  Roberto Echeverría
# 2                         22           5:16:44 h   Puro Trail Osorno
# 3                         22           5:34:13 h            Columbia
# 4                         22           5:54:14 h      Baguales Trail
#
#   athlete country  athlete year of birth athlete gender athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
# 2             CHI                 1987.0              M                  M23
# 3             ARG                 1976.0              M                  M40
# 4             CHI                 1992.0              M                  M23
#
#   athlete average speed  athlete id
# 0                10.286           0
# 1                 9.501           1
# 2                 9.472           2
# 3                 8.976           3
# 4                 8.469           4

# %%
# Only ITA races, 50k km, year 2020
df2 = df[(df['event distance/length'] == '50km') & (df['year of event'] == 2020) & (df['event name'].str.contains('ITA'))]
df2.head()
# Out:
#          year of event event dates                          event name  \
# 2613471           2020  23.02.2020  Terre di Siena Ultramarathon (ITA)
# 2613472           2020  23.02.2020  Terre di Siena Ultramarathon (ITA)
# 2613473           2020  23.02.2020  Terre di Siena Ultramarathon (ITA)
# 2613474           2020  23.02.2020  Terre di Siena Ultramarathon (ITA)
# 2613475           2020  23.02.2020  Terre di Siena Ultramarathon (ITA)
#
#         event distance/length  event number of finishers athlete performance  \
# 2613471                  50km                        462           3:23:24 h
# 2613472                  50km                        462           3:35:03 h
# 2613473                  50km                        462           3:47:58 h
# 2613474                  50km                        462           3:53:58 h
# 2613475                  50km                        462           3:55:08 h
#
#                    athlete club athlete country  athlete year of birth  \
# 2613471           POD. Ozzanese             ITA                 1981.0
# 2613472   POL. Dil. Santa Lucia             ITA                 1981.0
# 2613473  A.S.D. Risubbiani 2008             ITA                 1978.0
# 2613474        Marathon Cremona             ITA                 1989.0
# 2613475           Sevenlife SSD             ITA                 1974.0
#
#         athlete gender athlete age category athlete average speed  athlete id
# 2613471              M                  M35                14.749       36487
# 2613472              M                  M35                 13.95       89785
# 2613473              M                  M40                 13.16        3564
# 2613474              M                  M23                12.822       36509
# 2613475              M                  M45                12.759      826011

# %%
# Let's do a quick check regarding my filtering
print(df2['event distance/length'].unique())
print(df2['year of event'].unique())
print(df2['event name'].unique())
# Out:
# ['50km']
# [2020]
# ['Terre di Siena Ultramarathon (ITA)' 'Bettona Crossing (ITA)'
#  '6 Days UMF - 50 K (ITA)' 'Pantelleria Trail (ITA)'
#  'Ultra Beach 50 Km (ITA)']

# %%
# Drop NA and duplicates
df2 = df2.dropna()
df2 = df2.drop_duplicates()

# %%
# Let's check data types since I've been given an error about it
print('shape:', df2.shape)
print(df2.dtypes)
# Out:
# shape: (584, 13)
# year of event                  int64
# event dates                   object
# event name                    object
# event distance/length         object
# event number of finishers      int64
# athlete performance           object
# athlete club                  object
# athlete country               object
# athlete year of birth        float64
# athlete gender                object
# athlete age category          object
# athlete average speed         object
# athlete id                     int64
# dtype: object

# %%
# Fixing data types
df2['athlete year of birth'] = df2['athlete year of birth'].astype(int)
df2['event dates'] = pd.to_datetime(df2['event dates'], dayfirst = True)
df2['athlete average speed'] = df2['athlete average speed'].astype(float)

df2['event distance/length'] = df2['event distance/length'].str.extract('(\d+)', expand = False)
df2['event distance/length'] = pd.to_numeric(df2['event distance/length'])

df2.dtypes
# Out:
# year of event                         int64
# event dates                  datetime64[ns]
# event name                           object
# event distance/length                 int64
# event number of finishers             int64
# athlete performance                  object
# athlete club                         object
# athlete country                      object
# athlete year of birth                 int32
# athlete gender                       object
# athlete age category                 object
# athlete average speed               float64
# athlete id                            int64
# dtype: object

# %%
# Add the 'athlete age' comlumn. We don't have the exact birth date, so it will not be 100% accurate
df2['athlete age'] = 2020 - df2['athlete year of birth']
df2.head()
# Out:
#          year of event event dates                          event name  \
# 2613471           2020  2020-02-23  Terre di Siena Ultramarathon (ITA)
# 2613472           2020  2020-02-23  Terre di Siena Ultramarathon (ITA)
# 2613473           2020  2020-02-23  Terre di Siena Ultramarathon (ITA)
# 2613474           2020  2020-02-23  Terre di Siena Ultramarathon (ITA)
# 2613475           2020  2020-02-23  Terre di Siena Ultramarathon (ITA)
#
#          event distance/length  event number of finishers athlete performance  \
# 2613471                     50                        462           3:23:24 h
# 2613472                     50                        462           3:35:03 h
# 2613473                     50                        462           3:47:58 h
# 2613474                     50                        462           3:53:58 h
# 2613475                     50                        462           3:55:08 h
#
#                    athlete club athlete country  athlete year of birth  \
# 2613471           POD. Ozzanese             ITA                   1981
# 2613472   POL. Dil. Santa Lucia             ITA                   1981
# 2613473  A.S.D. Risubbiani 2008             ITA                   1978
# 2613474        Marathon Cremona             ITA                   1989
# 2613475           Sevenlife SSD             ITA                   1974
#
#         athlete gender athlete age category  athlete average speed  \
# 2613471              M                  M35                 14.749
# 2613472              M                  M35                 13.950
# 2613473              M                  M40                 13.160
# 2613474              M                  M23                 12.822
# 2613475              M                  M45                 12.759
#
#          athlete id  athlete age
# 2613471       36487           39
# 2613472       89785           39
# 2613473        3564           42
# 2613474       36509           31
# 2613475      826011           46

# %%
#Let's gather some statistical information about the dataset
df2.describe()
# Out:
#        year of event                    event dates  event distance/length  \
# count          584.0                            584                  584.0
# mean          2020.0  2020-04-23 20:35:20.547945216                   50.0
# min           2020.0            2020-02-23 00:00:00                   50.0
# 25%           2020.0            2020-02-23 00:00:00                   50.0
# 50%           2020.0            2020-02-23 00:00:00                   50.0
# 75%           2020.0            2020-09-26 00:00:00                   50.0
# max           2020.0            2020-10-17 00:00:00                   50.0
# std              0.0                            NaN                    0.0
#
#        event number of finishers  athlete year of birth  \
# count                 584.000000             584.000000
# mean                  369.551370            1971.849315
# min                     5.000000            1945.000000
# 25%                   147.000000            1966.000000
# 50%                   462.000000            1972.000000
# 75%                   462.000000            1978.000000
# max                   462.000000            1998.000000
# std                   149.722548               9.016160
#
#        athlete average speed     athlete id  athlete age
# count             584.000000     584.000000   584.000000
# mean                8.686914  369919.210616    48.150685
# min                 5.386000    2311.000000    22.000000
# 25%                 7.602000   36886.000000    42.000000
# 50%                 8.637500  217128.500000    48.000000
# 75%                 9.679500  742545.000000    54.000000
# max                14.749000  838692.000000    75.000000
# std                 1.555555  338522.316748     9.016160

# %%
# Let's visualize the athlete average speed distribution
sns.displot(df2[df2['event distance/length'] == 50]['athlete average speed'])
# Out:
# D:\Programmi\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# What about differences by athlete gender?
sns.boxplot(data = df2, x = 'event distance/length', y = 'athlete average speed', hue = 'athlete gender')
# Out:
# <Axes: xlabel='event distance/length', ylabel='athlete average speed'>

# %%
#What about differences by athlete gender and age?
sns.lmplot(data = df2, x = 'athlete age', y = 'athlete average speed', hue = 'athlete gender')

# %%
# Qestions about dataset

# %%
# 1. Is there any difference in speed between males and females?
df2.groupby(['event distance/length','athlete gender'])['athlete average speed'].mean()
# Out:
# event distance/length  athlete gender
# 50                     F                 8.421859
#                        M                 8.766608
# Name: athlete average speed, dtype: float64

# %%
# 2. What age groups are the best?
average_speed_by_age = df2.groupby('athlete age')['athlete average speed'].agg(['mean', 'count']).sort_values('mean', ascending = False)
average_speed_by_age.head()
# Out:
#                   mean  count
# athlete age
# 25           10.710000      1
# 33            9.685286      7
# 27            9.541500      2
# 37            9.471929     14
# 30            9.354000      3

# %%
sns.lineplot(data = average_speed_by_age,  x = 'athlete age', y = 'mean',).set(ylabel = 'average speed')
# Out:
# D:\Programmi\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Programmi\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# [Text(0, 0.5, 'average speed')]

# %%
# 3. What age groups are the worst?
average_speed_by_age_reverse = df2.groupby('athlete age')['athlete average speed'].agg(['mean', 'count']).sort_values('mean', ascending = True)
average_speed_by_age_reverse.head()
# Out:
#               mean  count
# athlete age
# 74           5.839      1
# 71           6.086      1
# 70           6.912      3
# 75           6.997      1
# 26           7.171      1

# %%
# 4. What italian event has the highest average athlete speed?
df2.groupby('event name')['athlete average speed'].agg(['mean', 'count']).sort_values('mean', ascending=False)
# Out:
#                                         mean  count
# event name
# Ultra Beach 50 Km (ITA)             9.543833     12
# Terre di Siena Ultramarathon (ITA)  9.111012    420
# Bettona Crossing (ITA)              7.471150    147
# Pantelleria Trail (ITA)             6.749600      5
